# %% [markdown]
# <a href="https://www.kaggle.com/code/anjusukumaran4/zomato-restaurants-data-eda?scriptVersionId=136203084" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Zomato Restaurants Data - Exploratory Data analysis

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Load data

# %%
#reading the dataset and encoding it  
df1=pd.read_csv('/kaggle/input/zomato-restaurants-data/zomato.csv',encoding='ISO-8859-1')

# %% [markdown]
# ## EDA

# %%
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
df1.shape
# Out:
# (9551, 21)

# %%
df1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
#  15  Switch to order menu  9551 non-null   object
#  16  Price range           9551 non-null   int64
#  17  Aggregate rating      9551 non-null   float64
#  18  Rating color          9551 non-null   object
#  19  Rating text           9551 non-null   object
#  20  Votes                 9551 non-null   int64
# dtypes: float64(3), int64(5), object(13)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Checking for null values

# %%
df1.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# No null values here

# %%
# Review descriptive data
df1.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
df_country = pd.read_excel('/kaggle/input/zomato-restaurants-data/Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df=pd.merge(df1, df_country, on= 'Country Code', how= 'left')   #so we can get a final df with country name 
df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
#   Is delivering now Switch to order menu Price range Aggregate rating  \
# 0                No                   No           3              4.8
# 1                No                   No           3              4.5
#
#    Rating color  Rating text Votes      Country
# 0    Dark Green    Excellent   314  Phillipines
# 1    Dark Green    Excellent   591  Phillipines
#
# [2 rows x 22 columns]

# %%
#checking for null values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# No null values

# %%
#droping unwanted columns
df.drop(['Restaurant ID','Country Code','Locality Verbose','Longitude','Latitude'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#     Restaurant Name         City  \
# 0  Le Petit Souffle  Makati City
# 1  Izakaya Kikufuji  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality                    Cuisines  \
# 0   Century City Mall, Poblacion, Makati City  French, Japanese, Desserts
# 1  Little Tokyo, Legaspi Village, Makati City                    Japanese
#
#    Average Cost for two          Currency Has Table booking  \
# 0                  1100  Botswana Pula(P)               Yes
# 1                  1200  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                  No                No                   No            3
# 1                  No                No                   No            3
#
#    Aggregate rating Rating color Rating text  Votes      Country
# 0               4.8   Dark Green   Excellent    314  Phillipines
# 1               4.5   Dark Green   Excellent    591  Phillipines

# %% [markdown]
# ## Top 3 countries that uses zomato

# %%
top_3 = df['Country'].value_counts()[:3]
top_3
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Name: Country, dtype: int64

# %%
plt.pie(top_3,labels=top_3.index)                  #Plotting Pie Chart
circle = plt.Circle( (0,0), 0.5, color='white')    #Creating a Circle 
p=plt.gcf()                                        #Adding circle to the Pie Chart
p.gca().add_artist(circle)
plt.title("Top 3 countries that uses zomato")      #Add title

plt.show()

# %% [markdown]
# The top 3 countries that uses zomato are India, United States and United Kingdom

# %% [markdown]
# ## Top 10 countries that uses zomato

# %%
top_10 = df['Country'].value_counts()[:10].rename_axis('Country').reset_index(name='count')
top_10.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_0383d_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0383d_row1_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0383d_row2_col1, #T_0383d_row3_col1, #T_0383d_row4_col1, #T_0383d_row5_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_0383d_row6_col1, #T_0383d_row7_col1, #T_0383d_row8_col1, #T_0383d_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_0383d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0383d_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_0383d_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0383d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0383d_row0_col0" class="data row0 col0" >India</td>
#       <td id="T_0383d_row0_col1" class="data row0 col1" >8652</td>
#     </tr>
#     <tr>
#       <th id="T_0383d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0383d_row1_col0" class="data row1 col0" >United States</td>
#       <td id="T_0383d_row1_col1" class="data row1 col1" >434</td>
#     </tr>
#     <tr>
#       <th id="T_0383d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0383d_row2_col0" class="data row2 col0" >United Kingdom</td>
#       <td id="T_0383d_row2_col1" class="data row2 col1" >80</td>
#     </tr>
#     <tr>
#       <th id="T_0383d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0383d_row3_col0" class="data row3 col0" >Brazil</td>
#       <td id="T_0383d_row3_col1" class="data row3 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_0383d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0383d_row4_col0" class="data row4 col0" >UAE</td>
#       <td id="T_0383d_row4_col1" class="data row4 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_0383d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0383d_row5_col0" class="data row5 col0" >South Africa</td>
#       <td id="T_0383d_row5_col1" class="data row5 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_0383d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0383d_row6_col0" class="data row6 col0" >New Zealand</td>
#       <td id="T_0383d_row6_col1" class="data row6 col1" >40</td>
#     </tr>
#     <tr>
#       <th id="T_0383d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0383d_row7_col0" class="data row7 col0" >Turkey</td>
#       <td id="T_0383d_row7_col1" class="data row7 col1" >34</td>
#     </tr>
#     <tr>
#       <th id="T_0383d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0383d_row8_col0" class="data row8 col0" >Australia</td>
#       <td id="T_0383d_row8_col1" class="data row8 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_0383d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0383d_row9_col0" class="data row9 col0" >Phillipines</td>
#       <td id="T_0383d_row9_col1" class="data row9 col1" >22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Countries with minimun transactions

# %%
df['Country'].value_counts()[-3:].rename_axis('Country').reset_index(name='count').style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_dbb28_row0_col1, #T_dbb28_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_dbb28_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_dbb28">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbb28_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_dbb28_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbb28_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbb28_row0_col0" class="data row0 col0" >Qatar</td>
#       <td id="T_dbb28_row0_col1" class="data row0 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_dbb28_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dbb28_row1_col0" class="data row1 col0" >Sri Lanka</td>
#       <td id="T_dbb28_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_dbb28_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dbb28_row2_col0" class="data row2 col0" >Canada</td>
#       <td id="T_dbb28_row2_col1" class="data row2 col1" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Most popular Cuisines

# %%
popular_cuisines=df['Cuisines'].value_counts()[:10].rename_axis('Cuisines').reset_index(name='count')
popular_cuisines.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c84c8_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c84c8_row1_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_c84c8_row2_col1, #T_c84c8_row3_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_c84c8_row4_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_c84c8_row5_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_c84c8_row6_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_c84c8_row7_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_c84c8_row8_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_c84c8_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_c84c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c84c8_level0_col0" class="col_heading level0 col0" >Cuisines</th>
#       <th id="T_c84c8_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c84c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c84c8_row0_col0" class="data row0 col0" >North Indian</td>
#       <td id="T_c84c8_row0_col1" class="data row0 col1" >936</td>
#     </tr>
#     <tr>
#       <th id="T_c84c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c84c8_row1_col0" class="data row1 col0" >North Indian, Chinese</td>
#       <td id="T_c84c8_row1_col1" class="data row1 col1" >511</td>
#     </tr>
#     <tr>
#       <th id="T_c84c8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c84c8_row2_col0" class="data row2 col0" >Chinese</td>
#       <td id="T_c84c8_row2_col1" class="data row2 col1" >354</td>
#     </tr>
#     <tr>
#       <th id="T_c84c8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c84c8_row3_col0" class="data row3 col0" >Fast Food</td>
#       <td id="T_c84c8_row3_col1" class="data row3 col1" >354</td>
#     </tr>
#     <tr>
#       <th id="T_c84c8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c84c8_row4_col0" class="data row4 col0" >North Indian, Mughlai</td>
#       <td id="T_c84c8_row4_col1" class="data row4 col1" >334</td>
#     </tr>
#     <tr>
#       <th id="T_c84c8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c84c8_row5_col0" class="data row5 col0" >Cafe</td>
#       <td id="T_c84c8_row5_col1" class="data row5 col1" >299</td>
#     </tr>
#     <tr>
#       <th id="T_c84c8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c84c8_row6_col0" class="data row6 col0" >Bakery</td>
#       <td id="T_c84c8_row6_col1" class="data row6 col1" >218</td>
#     </tr>
#     <tr>
#       <th id="T_c84c8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c84c8_row7_col0" class="data row7 col0" >North Indian, Mughlai, Chinese</td>
#       <td id="T_c84c8_row7_col1" class="data row7 col1" >197</td>
#     </tr>
#     <tr>
#       <th id="T_c84c8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c84c8_row8_col0" class="data row8 col0" >Bakery, Desserts</td>
#       <td id="T_c84c8_row8_col1" class="data row8 col1" >170</td>
#     </tr>
#     <tr>
#       <th id="T_c84c8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c84c8_row9_col0" class="data row9 col0" >Street Food</td>
#       <td id="T_c84c8_row9_col1" class="data row9 col1" >149</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.title("Most popular Cuisines")   #add title

sns.scatterplot(y=popular_cuisines['Cuisines'],x=popular_cuisines['count'],hue=popular_cuisines['Cuisines'])
# Out:
# <AxesSubplot: title={'center': 'Most popular Cuisines'}, xlabel='count', ylabel='Cuisines'>

# %% [markdown]
# the top most popular Cuisines are North Indian and chinese

# %%
# Analysing 'Has Online delivery' column

df['Has Online delivery' ].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %% [markdown]
# Most of the restaurants have no online delivery

# %%
sns.countplot(x='Has Online delivery',data=df,palette=['red','green'])
# Out:
# <AxesSubplot: xlabel='Has Online delivery', ylabel='count'>

# %%
# Which Countries do have online deliveries option

df[df['Has Online delivery']=='Yes'].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %% [markdown]
# Online Deliveries are availabe only in india and UAE

# %%
# Analysing 'Rating color' column

sns.countplot(x='Rating color',data=df,palette=['darkgreen','green','yellow','orange','grey','red'])
# Out:
# <AxesSubplot: xlabel='Rating color', ylabel='count'>

# %%
# Analysing 'Average Cost for two' column

by_rating=df.groupby(['Rating color']).mean().round()
by_rating
# Out:
#               Average Cost for two  Price range  Aggregate rating  Votes
# Rating color
# Dark Green                  8137.0          3.0               5.0  852.0
# Green                       3556.0          3.0               4.0  520.0
# Orange                       568.0          2.0               3.0   48.0
# Red                          638.0          2.0               2.0   91.0
# White                        340.0          1.0               0.0    1.0
# Yellow                      1045.0          2.0               4.0  229.0

# %%
plt.title("Aggregate rating vs Average Cost for two")     #Add title

sns.barplot(x=by_rating['Aggregate rating'],y=by_rating['Average Cost for two'])
# Out:
# <AxesSubplot: title={'center': 'Aggregate rating vs Average Cost for two'}, xlabel='Aggregate rating', ylabel='Average Cost for two'>

# %% [markdown]
# Top rated restaurants have high average cost

# %%
# Analysing 'Rating text' column

plt.title("Rating text vs Average Cost for two")     #Add title
sns.barplot(x=df['Rating text'],y=df['Average Cost for two'],palette=['cyan','orange', 'red', 'green', 'blue','grey'])
# Out:
# <AxesSubplot: title={'center': 'Rating text vs Average Cost for two'}, xlabel='Rating text', ylabel='Average Cost for two'>

# %% [markdown]
# ## Combining different features

# %%
# to create a table with selected features for better understanding
df.groupby(['Rating color','Aggregate rating','Rating text']).mean().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_36520_row0_col0, #T_36520_row12_col0, #T_36520_row16_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_36520_row0_col1 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_36520_row0_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_36520_row1_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_36520_row1_col1, #T_36520_row4_col2 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_36520_row1_col2 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_36520_row2_col0, #T_36520_row10_col0, #T_36520_row11_col0, #T_36520_row14_col2, #T_36520_row17_col0, #T_36520_row18_col0, #T_36520_row24_col0, #T_36520_row25_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_36520_row2_col1 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_36520_row2_col2 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_36520_row3_col0, #T_36520_row28_col0, #T_36520_row29_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_36520_row3_col1, #T_36520_row3_col2, #T_36520_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_36520_row4_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_36520_row5_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_36520_row5_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_36520_row5_col2 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_36520_row6_col0 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_36520_row6_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_36520_row6_col2 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_36520_row7_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_36520_row7_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_36520_row7_col2 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_36520_row8_col0, #T_36520_row31_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_36520_row8_col1 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_36520_row8_col2, #T_36520_row32_col1 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_36520_row9_col0 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_36520_row9_col1 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_36520_row9_col2 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_36520_row10_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_36520_row10_col2, #T_36520_row23_col2, #T_36520_row32_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_36520_row11_col1 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_36520_row11_col2, #T_36520_row12_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_36520_row12_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_36520_row13_col0, #T_36520_row14_col0, #T_36520_row15_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_36520_row13_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_36520_row13_col2, #T_36520_row16_col2, #T_36520_row19_col0, #T_36520_row31_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_36520_row14_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_36520_row15_col1, #T_36520_row28_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_36520_row15_col2, #T_36520_row23_col0, #T_36520_row26_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_36520_row16_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_36520_row17_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_36520_row17_col2, #T_36520_row20_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_36520_row18_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_36520_row18_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_36520_row19_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_36520_row19_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_36520_row20_col1 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_36520_row20_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_36520_row21_col0, #T_36520_row27_col0, #T_36520_row27_col1, #T_36520_row27_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_36520_row21_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_36520_row21_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_36520_row22_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_36520_row22_col1 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_36520_row22_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_36520_row23_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_36520_row24_col1 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_36520_row24_col2, #T_36520_row26_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_36520_row25_col1 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_36520_row25_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_36520_row26_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_36520_row28_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_36520_row29_col1 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_36520_row29_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_36520_row30_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_36520_row30_col1 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_36520_row30_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_36520_row31_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_36520_row32_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# </style>
# <table id="T_36520">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36520_level0_col0" class="col_heading level0 col0" >Average Cost for two</th>
#       <th id="T_36520_level0_col1" class="col_heading level0 col1" >Price range</th>
#       <th id="T_36520_level0_col2" class="col_heading level0 col2" >Votes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Rating color</th>
#       <th class="index_name level1" >Aggregate rating</th>
#       <th class="index_name level2" >Rating text</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36520_level0_row0" class="row_heading level0 row0" rowspan="5">Dark Green</th>
#       <th id="T_36520_level1_row0" class="row_heading level1 row0" >4.500000</th>
#       <th id="T_36520_level2_row0" class="row_heading level2 row0" >Excellent</th>
#       <td id="T_36520_row0_col0" class="data row0 col0" >542.263158</td>
#       <td id="T_36520_row0_col1" class="data row0 col1" >2.652632</td>
#       <td id="T_36520_row0_col2" class="data row0 col2" >716.157895</td>
#     </tr>
#     <tr>
#       <th id="T_36520_level1_row1" class="row_heading level1 row1" >4.600000</th>
#       <th id="T_36520_level2_row1" class="row_heading level2 row1" >Excellent</th>
#       <td id="T_36520_row1_col0" class="data row1 col0" >15455.128205</td>
#       <td id="T_36520_row1_col1" class="data row1 col1" >2.756410</td>
#       <td id="T_36520_row1_col2" class="data row1 col2" >731.102564</td>
#     </tr>
#     <tr>
#       <th id="T_36520_level1_row2" class="row_heading level1 row2" >4.700000</th>
#       <th id="T_36520_level2_row2" class="row_heading level2 row2" >Excellent</th>
#       <td id="T_36520_row2_col0" class="data row2 col0" >597.380952</td>
#       <td id="T_36520_row2_col1" class="data row2 col1" >2.857143</td>
#       <td id="T_36520_row2_col2" class="data row2 col2" >1089.166667</td>
#     </tr>
#     <tr>
#       <th id="T_36520_level1_row3" class="row_heading level1 row3" >4.800000</th>
#       <th id="T_36520_level2_row3" class="row_heading level2 row3" >Excellent</th>
#       <td id="T_36520_row3_col0" class="data row3 col0" >727.000000</td>
#       <td id="T_36520_row3_col1" class="data row3 col1" >3.240000</td>
#       <td id="T_36520_row3_col2" class="data row3 col2" >1197.880000</td>
#     </tr>
#     <tr>
#       <th id="T_36520_level1_row4" class="row_heading level1 row4" >4.900000</th>
#       <th id="

# %% [markdown]
# The Zomato API Analysis is one of the most useful analysis for foodies who want to taste the best cuisines of every part of the world which lies in their budget. By analysing the dataset we can see that the number one consumer of Zomato is India followed by United States and United Kingdom. There are many restaurants listed in Zomato with different prize range and rating with popular Cuisines like North Indian and chinese but, the top rated restaurants have always high average cost and are usually under Dark Green rating colour. One more observation from this dataset is that most of the restaurants have no online delivery option specifically, online deliveries are availabe only in India and UAE.
